# %%
import numpy as np
import matplotlib.pyplot as plt

# %%
spikes = np.load('2photon/s2p/suite2p/plane0/spks.npy')

# %%
len(spikes)
# Out:
# 837

# %%
plt.plot(spikes[0])

# %%
stats = np.load('2photon/s2p/suite2p/plane0/stat.npy', allow_pickle=True)
